# %% [markdown]
# <a href="https://colab.research.google.com/github/AKHILESH-create/AIML-Concepts/blob/main/AI_Training8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ML AND DL CONCEPTS

# %%
#linear or non linear with code example
#what is multi class classification
